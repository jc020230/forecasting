# %% [markdown]
# <a href="https://colab.research.google.com/github/jc020230/forecasting/blob/main/ch02_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ch2. Time Series Graphics
# **Forecasting: Principles & Practice (Python Edition)**
# Lab Notebook · [github.com/bcseong2/fpppy-labs](https://github.com/bcseong2/fpppy-labs)

# %%
# %pip install statsforecast neuralforecast hierarchicalforecast mlforecast utilsforecast
# Out:
# Collecting statsforecast
#   Downloading statsforecast-2.1.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (26 kB)
# Collecting neuralforecast
#   Downloading neuralforecast-3.2.2-py3-none-any.whl.metadata (14 kB)
# Collecting hierarchicalforecast
#   Downloading hierarchicalforecast-1.5.1-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting mlforecast
#   Downloading mlforecast-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting utilsforecast
#   Downloading utilsforecast-0.2.16-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.13/dist-packages (from statsforecast) (3.1.2)
# Collecting coreforecast>=0.0.17 (from statsforecast)
#   Downloading coreforecast-0.0.18-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.13/dist-packages (from statsforecast) (2.1.3)
# Requirement already satisfied: pandas<3.0.0 in /usr/local/lib/python3.13/dist-packages (from statsforecast) (2.2.3)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.13/dist-packages (from statsforecast) (1.16.3)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.13/dist-packages (from statsforecast) (0.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from statsforecast) (4.67.3)
# Collecting fugue>=0.9.4 (from statsforecast)
#   Downloading fugue-0.9.7-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: threadpoolctl>=3 in /usr/local/lib/python3.13/dist-packages (from statsforecast) (3.6.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.13/dist-packages (from neuralforecast) (2025.12.0)
# Requirement already satisfied: torch>=2.9.1 in /usr/local/lib/python3.13/dist-packages (from neuralforecast) (2.11.0+cpu)
# Requirement already satisfied: tornado>=6.5.5 in /usr/local/lib/python3.13/dist-packages (from neuralforecast) (6.5.7)
# Collecting pytorch-lightning<2.6.0,>=2.0.0 (from neuralforecast)
#   Downloading pytorch_lightning-2.5.6-py3-none-any.whl.metadata (20 kB)
# Collecting ray>=2.2.0 (from ray[train,tune]>=2.2.0->neuralforecast)
#   Downloading ray-2.58.0-cp313-cp313-manylinux2014_x86_64.whl.metadata (23 kB)
# Collecting optuna (from neuralforecast)
#   Downloading optuna-5.0.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.13/dist-packages (from hierarchicalforecast) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from hierarchicalforecast) (3.10.0)
# Requirement already satisfied: narwhals>=2.0 in /usr/local/lib/python3.13/dist-packages (from hierarchicalforecast) (2.25.0)
# Collecting qpsolvers[clarabel] (from hierarchicalforecast)
#   Downloading qpsolvers-4.13.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from utilsforecast) (26.3)
# Collecting triad>=1.0.1 (from fugue>=0.9.4->statsforecast)
#   Downloading triad-1.0.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting adagio>=0.2.6 (from fugue>=0.9.4->statsforecast)
#   Downloading adagio-0.2.6-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas<3.0.0->statsforecast) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas<3.0.0->statsforecast) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<3.0.0->statsforecast) (2026.3)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.13/dist-packages (from pytorch-lightning<2.6.0,>=2.0.0->neuralforecast) (6.0.3)
# Collecting torchmetrics>0.7.0 (from pytorch-lightning<2.6.0,>=2.0.0->neuralforecast)
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.13/dist-packages (from pytorch-lightning<2.6.0,>=2.0.0->neuralforecast) (4.16.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning<2.6.0,>=2.0.0->neuralforecast)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.13/dist-packages (from ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (8.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (3.32.5)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.13/dist-packages (from ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (4.26.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (1.2.2)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.13/dist-packages (from ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (5.29.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (2.32.4)
# Collecting tensorboardX>=1.9 (from ray[train,tune]>=2.2.0->neuralforecast)
#   Downloading tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pyarrow>=17.0.0 in /usr/local/lib/python3.13/dist-packages (from ray[train,tune]>=2.2.0->neuralforecast) (23.0.1)
# Requirement already satisfied: pydantic<3,>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from ray[train,tune]>=2.2.0->neuralforecast) (2.13.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.2->hierarchicalforecast) (1.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.13/dist-packages (from statsmodels>=0.14.5->statsforecast) (1.0.3)
# Requirement already satisfied: formulaic>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from statsmodels>=0.14.5->statsforecast) (1.2.2)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.9.1->neuralforecast) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.9.1->neuralforecast) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.9.1->neuralforecast) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=2.9.1->neuralforecast) (3.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->hierarchicalforecast) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->hierarchicalforecast) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->hierarchicalforecast) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->hierarchicalforecast) (1.5.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->hierarchicalforecast) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->hierarchicalforecast) (3.3.2)
# Collecting alembic>=1.5.0 (from optuna->neuralforecast)
#   Downloading alembic-1.20.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna->neuralforecast)
#   Downloading colorlog-6.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.13/dist-packages (from optuna->neuralforecast) (2.0.52)
# Requirement already satisfied: clarabel>=0.4.1 in /usr/local/lib/python3.13/dist-packages (from qpsolvers[clarabel]->hierarchicalforecast) (0.11.1)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->neuralforecast) (1.3.2.dev0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.13/dist-packages (from clarabel>=0.4.1->qpsolvers[clarabel]->hierarchicalforecast) (2.1.1)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels>=0.14.5->statsforecast) (2.0.1)
# Requirement already satisfied: wrapt>=1.17.0rc1 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels>=0.14.5->statsforecast) (2.4.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning<2.6.0,>=2.0.0->neuralforecast) (3.14.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=2.5.0->ray[train,tune]>=2.2.0->neuralforecast) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=2.5.0->ray[train,tune]>=2.2.0->neuralforecast) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=2.5.0->ray[train,tune]>=2.2.0->neuralforecast) (0.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0->statsforecast) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy>=1.4.2->optuna->neuralforecast) (3.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.9.1->neuralforecast) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=2.9.1->neuralforecast) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (2026.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (2026.7.22)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6.0,>=2.0.0->neuralforecast) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6.0,>=2.0.0->neuralforecast) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6.0,>=2.0.0->neuralforecast) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6.0,>=2.0.0->neuralforecast) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6.0,>=2.0.0->neuralforecast) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6.0,>=2.0.0->neuralforecast) (1.24.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi->clarabel>=0.4.1->qpsolvers[clarabel]->hierarchicalforecast) (3.0)
# Downloading statsforecast-2.1.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (501 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 501.8/501.8 kB 4.7 MB/s eta 0:00:00
# Downloading neuralforecast-3.2.2-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 11.7 MB/s eta 0:00:00
# Downloading hierarchicalforecast-1.5.1-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.8/306.8 kB 10.8 MB/s eta 0:00:00
# Downloading mlforecast-1.1.0-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.7/261.7 kB 13.3 MB/s eta 0:00:00
# Downloading utilsforecast-0.2.16-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 1.7 MB/s eta 0:00:00
# Downloading coreforecast-0.0.18-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (348 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.7/348.7 kB 18.9 MB/s eta 0:00:00
# Downloading fugue-0.9.7-py3-none-any.whl (281 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.0/281.0 kB 8.9 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.6-py3-none-any.whl (831 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.6/831.6 kB 19.6 MB/s eta 0:00:00
# Downloading ray-2.58.0-cp313-cp313-manylinux2014_x86_64.whl (78.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 MB 8.8 MB/s eta 0:00:00
# Downloading optuna-5.0.0-py3-none-any.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.4/442.4 kB 25.5 MB/s eta 0:00:00
# Downloading adagio-0.2.6-py3-none-any.whl (19 kB)
# Downloading alembic-1.20.0-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.7/268.7 kB 19.0 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading tensorboardx-2.6.5-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 5.8 MB/s eta 0:00:00
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 39.6 MB/s eta 0:00:00
# Downloading triad-1.0.2-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 3.7 MB/s eta 0:00:00
# Downloading colorlog-6.12.0-py3-none-any.whl (12 kB)
# Downloading qpsolvers-4.13.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.1/107.1 kB 8.4 MB/s eta 0:00:00
# Installing collected packages: tensorboardX, lightning-utilities, coreforecast, colorlog, qpsolvers, alembic, utilsforecast, triad, torchmetrics, optuna, ray, pytorch-lightning, mlforecast, hierarchicalforecast, adagio, fugue, statsforecast, neuralforecast
# Successfully installed adagio-0.2.6 alembic-1.20.0 colorlog-6.12.0 coreforecast-0.0.18 fugue-0.9.7 hierarchicalforecast-1.5.1 lightning-utilities-0.15.3 mlforecast-1.1.0 neuralforecast-3.2.2 optuna-5.0.0 pytorch-lightning-2.5.6 qpsolvers-4.13.0 ray-2.58.0 statsforecast-2.1.1 tensorboardX-2.6.5 torchmetrics-1.9.0 triad-1.0.2 utilsforecast-0.2.16

# %% [markdown]
# ## [Slide 2] 2.1 The Nixtlaverse Data Format

# %%
import pandas as pd

df = pd.DataFrame({
    "unique_id": "beer",
    "ds": pd.period_range("2000Q1", periods=10, freq="Q").to_timestamp(),
    "y": [443, 410, 420, 532, 433, 421, 410, 512, 449, 381],
})
print(df.head(3))
# Out:
#   unique_id         ds    y
# 0      beer 2000-01-01  443
# 1      beer 2000-04-01  410
# 2      beer 2000-07-01  420

# %% [markdown]
# ## [Slide 4] 2.1 Timestamps and Periods

# %%
import pandas as pd

# Timestamp: an instant in time
pd.Timestamp("2020-01")          # Timestamp('2020-01-01 00:00:00')

# Period: a span of time
pd.Period("2020-01", freq="M")   # Period('2020-01', 'M')

# Create sequences
ts_range = pd.date_range("2020-01-01", "2020-12-01", freq="MS")
p_range  = pd.period_range("2020Q1", periods=8, freq="Q")

# Convert Period -> Timestamp for plotting
p_range.to_timestamp()
# Out:
# DatetimeIndex(['2020-01-01', '2020-04-01', '2020-07-01', '2020-10-01',
#                '2021-01-01', '2021-04-01', '2021-07-01', '2021-10-01'],
#               dtype='datetime64[ns]', freq='QS-OCT')

# %% [markdown]
# ## [Slide 6] 2.1 Working with Time Series DataFrames

# %%
import pandas as pd

BASE = "https://raw.githubusercontent.com/bcseong2/fpppy-labs/refs/heads/main/data/"
pbs = pd.read_csv(
  BASE + "pbs.csv",
  parse_dates=["Month"],
  date_format={"Month": "%Y %b"} # "1991 Jul" 형식 명시
)

# Filter to one series
a10 = pbs.loc[pbs["ATC2"] == "A10"].copy()

# Remove unused columns
a10 = a10.drop(columns=["ATC1", "ATC2"])

# Aggregate: total cost across all products
total_cost = (
    pbs
    .groupby("Month", as_index=False)
    .agg({"Cost": "sum"})
    .assign(Cost=lambda x: (x["Cost"] / 1e6).round(2))
)

print(total_cost.head(3))
# Out:
#       Month    Cost
# 0  1991 Aug   83.07
# 1  1991 Dec  112.61
# 2  1991 Jul   90.49

# %% [markdown]
# ## [Slide 8] 2.2 Time Plots

# %%
import matplotlib.pyplot as plt
import pandas as pd, numpy as np

# Generate synthetic monthly series
dates = pd.date_range("2010-01", periods=120, freq="MS")
y = (100 + np.arange(120)*0.3
     + 8*np.sin(2*np.pi*np.arange(120)/12)
     + np.random.default_rng(1).normal(0, 2, 120))

fig, ax = plt.subplots(figsize=(7, 3.2))
ax.plot(dates, y, lw=1.2, color="steelblue")
ax.set(xlabel="Month", ylabel="Value",
       title="Monthly time series (2010-2019)")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## [Slide 10] 2.2 Using plot_series (utilsforecast)

# %%
import pandas as pd
from utilsforecast.plotting import plot_series

BASE = "https://raw.githubusercontent.com/bcseong2/fpppy-labs/main/data/"
ansett = pd.read_csv(BASE + "ansett.csv", parse_dates=["ds"])

# 컬럼 구조 확인
print(ansett.columns.tolist())      # 컬럼 목록
print(ansett["Airports"].unique())  # 노선 목록
print(ansett.head(3))               # 데이터 미리보기

# Economy 클래스만 필터링 → unique_id / ds / y 형식으로 변환
df = ansett[ansett["Class"] == "Economy"].copy()
df = df.rename(columns={"Airports": "unique_id"})[["unique_id", "ds", "y"]]

# 다중 시계열 시각화 (노선별 서브플롯)
plot_series(df, id_col="unique_id", time_col="ds", target_col="y")
# Out:
# ['ds', 'Airports', 'Class', 'y']
# ['ADL-PER' 'MEL-ADL' 'MEL-BNE' 'MEL-OOL' 'MEL-PER' 'MEL-SYD' 'SYD-ADL'
#  'SYD-BNE' 'SYD-OOL' 'SYD-PER']
#           ds Airports     Class    y
# 0 1989-07-10  ADL-PER  Business  193
# 1 1989-07-17  ADL-PER  Business  254
# 2 1989-07-24  ADL-PER  Business  185

# %% [markdown]
# ## [Slide] 2.2 다중 시계열 겹쳐 그리기

# %%
import pandas as pd
import matplotlib.pyplot as plt

BASE = "https://raw.githubusercontent.com/bcseong2/fpppy-labs/main/data/"
ansett = pd.read_csv(BASE + "ansett.csv", parse_dates=["ds"])

# Economy 클래스만 필터링
df = ansett[ansett["Class"] == "Economy"].copy()
df = df.rename(columns={"Airports": "unique_id"})[["unique_id", "ds", "y"]]

# 여러 시계열을 같은 축에 겹쳐 그리기
fig, ax = plt.subplots()
for uid, grp in df.groupby("unique_id"):
    ax.plot(grp["ds"], grp["y"], label=uid, lw=1)
ax.set_xlabel("Week")
ax.set_ylabel("Passengers")
ax.legend(fontsize=7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## [Slide 13] 2.4 Seasonal Plots

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

dates = pd.date_range("2000-01", periods=120, freq="MS")
y = (50 + 5*np.sin(2*np.pi*np.arange(120)/12)
     + np.random.default_rng(7).normal(0, 1, 120))
df = pd.DataFrame({"ds": dates, "y": y})
df["year"]  = df["ds"].dt.year
df["month"] = df["ds"].dt.month

fig, ax = plt.subplots(figsize=(7, 3.2))
for yr, g in df.groupby("year"):
    ax.plot(g["month"], g["y"], lw=1, alpha=0.7, label=str(yr))
ax.set(xlabel="Month", ylabel="Value",
       title="Seasonal plot: monthly series")
ax.set_xticks(range(1, 13))
plt.tight_layout(); plt.show()

# %% [markdown]
# ## [Slide 16] 2.5 Seasonal Subseries Plots

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

dates = pd.date_range("2005-01", periods=180, freq="MS")
y = (50 + 5*np.sin(2*np.pi*np.arange(180)/12)
     + 0.15*np.arange(180)
     + np.random.default_rng(3).normal(0, 1.5, 180))
df = pd.DataFrame({"ds": dates, "y": y,
                   "month": dates.month, "year": dates.year})

fig, axes = plt.subplots(1, 12, figsize=(14, 3.2), sharey=True)
for m, ax in enumerate(axes, 1):
    sub = df[df["month"] == m]
    ax.plot(sub["year"], sub["y"], "o-", ms=3, lw=1)
    ax.axhline(sub["y"].mean(), color="blue", lw=1.5)
    ax.set_title(f"M{m}", fontsize=7)
    ax.tick_params(axis="x", labelsize=5, rotation=45)
plt.suptitle("Seasonal subseries plot", y=1.02)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## [Slide] 2.6 Scatterplots and Correlation

# %%
import pandas as pd, matplotlib.pyplot as plt

BASE = "https://raw.githubusercontent.com/bcseong2/fpppy-labs/main/data/"
ins = pd.read_csv(BASE + "insurance.csv", parse_dates=["ds"])

fig, axes = plt.subplots(1, 2, figsize=(10, 3.5))

# 시계열 플롯
axes[0].plot(ins["ds"], ins["Quotes"],    label="Quotes",    lw=1.5)
axes[0].plot(ins["ds"], ins["TVadverts"], label="TVadverts", lw=1.5, linestyle="--")
axes[0].set_title("Time Series"); axes[0].legend(fontsize=8)

# 산점도
axes[1].scatter(ins["TVadverts"], ins["Quotes"], alpha=0.7, s=30, color="steelblue")
axes[1].set(xlabel="TV Adverts", ylabel="Quotes", title="Quotes vs. TVadverts")

r = ins["Quotes"].corr(ins["TVadverts"])
axes[1].annotate(f"r = {r:.2f}", xy=(0.05, 0.90), xycoords="axes fraction", fontsize=10)

plt.tight_layout(); plt.show()

# %% [markdown]
# ## [Slide 22] 2.6 Scatterplot Matrices

# %%
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt

BASE = "https://raw.githubusercontent.com/bcseong2/fpppy-labs/main/data/"
tour = pd.read_csv(BASE + "tourism.csv", parse_dates=["ds"])

print(tour.head(5))

# Long → Wide 변환: 주(State)별 Holiday 방문객 합산
tourism_wide = (
    tour[tour["Purpose"] == "Holiday"]
    .groupby(["ds", "State"])["y"].sum()
    .unstack("State")
)

print(tourism_wide.head(5))

sns.pairplot(
    tourism_wide,
    diag_kind="kde",
    plot_kws={"alpha": 0.3, "s": 10},
)
plt.suptitle("Quarterly Holiday Trips by State", y=1.01)
plt.tight_layout(); plt.show()
# Out:
#           ds    Region            State   Purpose           y
# 0 1998-01-01  Adelaide  South Australia  Business  135.077690
# 1 1998-04-01  Adelaide  South Australia  Business  109.987316
# 2 1998-07-01  Adelaide  South Australia  Business  166.034687
# 3 1998-10-01  Adelaide  South Australia  Business  127.160464
# 4 1999-01-01  Adelaide  South Australia  Business  137.448533
# State              ACT  New South Wales  Northern Territory   Queensland  \
# ds
# 1998-01-01  196.218550      4032.909833           59.810033  2031.363366
# 1998-04-01  126.770597      3262.232745          163.012551  1661.299812
# 1998-07-01  110.679645      2680.582360          360.376363  2164.351780
# 1998-10-01  170.472206      3082.677044          114.407975  1969.206548
# 1999-01-01  107.779245      3634.931012           56.243100  2139.972390
#
# State       South Australia    Tasmania     Victoria  Western Australia
# ds
# 1998-01-01       877.023426  632.560900  3203.621030         772.530484
# 1998-04-01       671.224032  413.613629  2257.810939         719.697768
# 1998-07-01       507.004314  166.185539  1898.378966         754.929622
# 1998-10-01       741.206038  403.952501  2003.781150         813.820318
# 1999-01-01       810.047640  560.531428  2919.494622         943.027619

# %% [markdown]
# ## [Slide 24] 2.7 Lag Plots

# %%
import pandas as pd, matplotlib.pyplot as plt

BASE = "https://raw.githubusercontent.com/bcseong2/fpppy-labs/main/data/"
aus = pd.read_csv(BASE + "aus_production.csv", parse_dates=["ds"])
beer = aus[["ds", "Beer"]].rename(columns={"Beer": "y"})
beer = beer.sort_values("ds").reset_index(drop=True)

fig, axes = plt.subplots(2, 4, figsize=(10, 5))
for ax, k in zip(axes.flat, range(1, 9)):
    ax.scatter(beer["y"].shift(k), beer["y"],
               alpha=0.5, s=10, c=beer.index % 4,
               cmap="tab10")
    ax.set(title=f"Lag {k}", xlabel=f"$y_{{t-{k}}}$", ylabel="$y_t$")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## [Slide 27] 2.8 Autocorrelation

# %%
import statsmodels.api as sm

acf_vals = sm.tsa.acf(beer["y"], nlags=9, fft=False)
print(acf_vals)
# Out:
# [1.         0.68361007 0.49986057 0.66666801 0.93996999 0.64390629
#  0.45765188 0.62143982 0.88738908 0.59819753]

# %% [markdown]
# ## [Slide 29] 2.8 Plotting the ACF (Correlogram)

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7, 3.5))
plot_acf(
    beer["y"],
    lags=16,
    ax=ax,
    zero=False,          # omit lag-0 (always = 1)
    bartlett_confint=False,
)
ax.set(xlabel="Lag", ylabel="ACF",
       title="ACF: Quarterly Australian Beer Production")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## [Slide 33] 2.9 Generating and Testing White Noise

# %%
import numpy as np, matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

rng = np.random.default_rng(99)
wn = rng.standard_normal(50)   # white noise series

fig, axes = plt.subplots(1, 2, figsize=(10, 3.2))

# Time plot
axes[0].plot(wn, lw=1, color="steelblue")
axes[0].axhline(0, color="gray", lw=0.8, ls="--")
axes[0].set(title="White noise series (T=50)",
            xlabel="t", ylabel="$e_t$")

# ACF
plot_acf(wn, lags=20, ax=axes[1], zero=False)
axes[1].set(title=f"ACF (bounds ≈ ±{1.96/50**0.5:.2f})")

plt.tight_layout(); plt.show()

# %% [markdown]
# ## [Slide 35] 2.9 Residual Checking with ACF

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

lb = acorr_ljungbox(wn, lags=[10], return_df=True)
print(lb)   # lb_stat, lb_pvalue
# Out:
#      lb_stat  lb_pvalue
# 10  13.06971     0.2198
